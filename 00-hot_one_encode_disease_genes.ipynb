# %%
import numpy as np
import pandas as pd
import os, glob
from sklearn.preprocessing import OneHotEncoder

# %%
path = glob.glob("raw_data/*.tsv")
thr = [0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 1.0]
for m in thr:
    for n in range (0,len(path)):
        dis = pd.read_csv(path[n], delimiter = '\t')
        dis = dis[['symbol', 'objectObject']]  # Take gene symbol and column containing genetic association score
        dis = dis[dis['objectObject']>m]  # Filter based on chosen risk threshold 
        disease = glob.glob("raw_data/*.tsv")[n].split("\\")[1].split("_")[0]  # get disease name
        print(disease)
        if np.shape(dis)[0]>10:
                dis['score']=int(1)
                dis = dis.drop(columns=['objectObject']).set_index(['symbol'])

                #creating instance of one-hot-encoder
                encoder = OneHotEncoder(handle_unknown='ignore')
                encoder_df = pd.DataFrame(encoder.fit_transform(dis).toarray())
                encoder_df[disease] = encoder_df[0]
                encoder_df = encoder_df.drop(columns=[0])
                encoder_df['genes'] = list(dis.index)
                encoder_df.set_index('genes', inplace=True)
                if n==0:
                    alldis = encoder_df
                else:
                    alldis = pd.merge(alldis, encoder_df, how='outer', left_index=True, right_index=True).fillna(0)
        else:
            print(disease, " doesn't have enough genes with high genetic scores.")

    alldis.to_csv('processed_data/hot-encoded-diseases_%f.csv' % m)
# Out:
# AD
#          AD
# genes
# PSEN1   1.0
# APP     1.0
# PSEN2   1.0
# ACE     1.0
# UNC5C   1.0
# ...     ...
# MINK1   1.0
# USP50   1.0
# PSMC6   1.0
# GRXCR2  1.0
# USP35   1.0
#
# [238 rows x 1 columns]
# ALS
#           ALS
# genes
# SOD1      1.0
# FUS       1.0
# ALS2      1.0
# SETX      1.0
# TARDBP    1.0
# ...       ...
# XPOT      1.0
# LAMB3     1.0
# TNFAIP1   1.0
# C12orf56  1.0
# ZDHHC6    1.0
#
# [112 rows x 1 columns]
# AnorexiaNervosa
#          AnorexiaNervosa
# genes
# DRD2                 1.0
# TCF4                 1.0
# SORCS3               1.0
# CADM1                1.0
# CACNA1C              1.0
# ...                  ...
# SF3B1                1.0
# NT5C2                1.0
# TOPAZ1               1.0
# RBKS                 1.0
# DNAJC19              1.0
#
# [237 rows x 1 columns]
# BipolarDisorder
#           BipolarDisorder
# genes
# DRD2                  1.0
# SCN2A                 1.0
# GRIN2A                1.0
# SCN3A                 1.0
# ALOX5AP               1.0
# ...                   ...
# BTBD1                 1.0
# TCF20                 1.0
# ADGRB1                1.0
# CTTN                  1.0
# METTL21A              1.0
#
# [512 rows x 1 columns]
# BrainAneurysm
#          BrainAneurysm
# genes
# THSD1              1.0
# EDNRA              1.0
# CDKN2B             1.0
# PDE3A              1.0
# STARD13            1.0
# ...                ...
# TCF24              1.0
# CUL4A              1.0
# PSMA4              1.0
# BORCS7             1.0
# RTP5               1.0
#
# [77 rows x 1 columns]
# CerebelarAmyloidAngiopathy
# CerebelarAmyloidAngiopathy  doesn't have enough genes with high genetic scores.
# EssentialTremor
#                  EssentialTremor
# genes
# TENM4                        1.0
# FUS                          1.0
# C19orf12                     1.0
# HARS1                        1.0
# NOTCH2NLC                    1.0
# STXBP1                       1.0
# SCN4A                        1.0
# TMEM67                       1.0
# DNAJC13                      1.0
# DRD3                         1.0
# STK32B                       1.0
# LINGO1                       1.0
# MPZ                          1.0
# FIG4                         1.0
# NAT2                         1.0
# GPR151                       1.0
# MT-ATP6                      1.0
# TGM4                         1.0
# CCDC183                      1.0
# DNHD1                        1.0
# ZNF528                       1.0
# LRRTM3                       1.0
# GBA1                         1.0
# DHX15                        1.0
# CACNA1H                      1.0
# ENSG00000260272              1.0
# GLI2                         1.0
# TBC1D24                      1.0
# ADGRV1                       1.0
# SYNE1                        1.0
# FAM228B                      1.0
# SH3D19                       1.0
# OR5K3                        1.0
# MMP10                        1.0
# MS4A14                       1.0
# PRSS48                       1.0
# GEMIN5                       1.0
# MYO6                         1.0
# OR5K4                        1.0
# OR6C1                        1.0
# PKD1L3                       1.0
# FrontotemporalDementia
#                  FrontotemporalDementia
# genes
# CHMP2B                              1.0
# GRN                                 1.0
# MAPT                                1.0
# PSEN1                               1.0
# SQSTM1                              1.0
# TMEM106B                            1.0
# TARDBP                              1.0
# TREM2                               1.0
# SETX                                1.0
# CYLD                                1.0
# CHRNB4                              1.0
# MEF2C                               1.0
# CSF1R                               1.0
# TBK1                                1.0
# GFRA2                               1.0
# CHRNA4                              1.0
# FUS                                 1.0
# HNRNPA2B1                           1.0
# CCNF                                1.0
# OPTN                                1.0
# ERBB4                               1.0
# DCTN1                               1.0
# ANG                                 1.0
# GLT8D1                              1.0
# RNASE4                              1.0
# ENSG00000259171                     1.0
# ABCA7                               1.0
# HLA-DRA                             1.0
# ARSA                                1.0
# VPS13C                              1.0
# TNK1                                1.0
# TM2D3                               1.0
# MIR4795                             1.0
# LRRK2                               1.0
# MARCHF4                             1.0
# IntracranialHemorrhage
#             IntracranialHemorrhage
# genes
# COL4A1                         1.0
# COL4A2                         1.0
# ACE                            1.0
# KAT6B                          1.0
# DLX5                           1.0
# ADGRG1                         1.0
# PWWP2B                         1.0
# APOC1                          1.0
# PMF1-BGLAP                     1.0
# PIRT                           1.0
# DPH1                           1.0
# ZBTB46                         1.0
# ICA1L                          1.0
# MEGF6                          1.0
# TMEM238L                       1.0
# PMF1                           1.0
# CARF                           1.0
# DLX6                           1.0
# RTN4RL1                        1.0
# WDR12                          1.0
# SLC25A44                       1.0
# LBD
#          LBD
# genes
# SNCA     1.0
# GBA1     1.0
# SNCB     1.0
# APOE     1.0
# BIN1     1.0
# TMEM175  1.0
# IDUA     1.0
# ASH1L    1.0
# TOMM40   1.0
# GAK      1.0
# APOC1    1.0
# STX1B    1.0
# MMRN1    1.0
# HSD3B7   1.0
# MajorDepressiveDisorder
#         MajorDepressiveDisorder
# genes
# DRD2                        1.0
# TCF4                        1.0
# LRFN5                       1.0
# NEGR1                       1.0
# TPH2                        1.0
# ...                         ...
# ITIH4                       1.0
# BSN                         1.0
# KLC1                        1.0
# TRIM27                      1.0
# FCF1                        1.0
#
# [105 rows x 1 columns]
# MigraineDisorder
#          MigraineDisorder
# genes
# SCN1A                 1.0
# CACNA1A               1.0
# ATP1A2                1.0
# CALCB                 1.0
# CALCA                 1.0
# ...                   ...
# ACTRT2                1.0
# NKX6-2                1.0
# ECM1                  1.0
# ZNF620                1.0
# TBC1D7                1.0
#
# [143 rows x 1 columns]
# MigraineWithAura
#          MigraineWithAura
# genes
# CACNA1A               1.0
# SCN1A                 1.0
# ATP1A2                1.0
# NOTCH3                1.0
# PRRT2                 1.0
# IRAG1                 1.0
# FHL5                  1.0
# UFL1                  1.0
# STAT6                 1.0
# LRP1                  1.0
# DGUOK                 1.0
# LYVE1                 1.0
# MS
#           MS
# genes
# KEAP1    1.0
# IL2RA    1.0
# KCNH8    1.0
# CD58     1.0
# IL7R     1.0
# ...      ...
# SPRYD7   1.0
# TMA16    1.0
# GLMN     1.0
# RHOH     1.0
# RASGRF1  1.0
#
# [324 rows x 1 columns]
# NarcolepsyCataplexy
#              NarcolepsyCataplexy
# genes
# MOG                          1.0
# HCRT                         1.0
# PPAN-P2RY11                  1.0
# PPAN                         1.0
# EIF3G                        1.0
# NPC1                         1.0
# CTSH                         1.0
# TNFSF4                       1.0
# IFNAR1                       1.0
# HLA-DQA2                     1.0
# HLA-DRB1                     1.0
# HLA-DQB1                     1.0
# IL10RB                       1.0
# ZNF365                       1.0
# H2AC6                        1.0
# DAD1                         1.0
# P2RY11                       1.0
# EGR2                         1.0
# HFE                          1.0
# ADO                          1.0
# TNFSF18                      1.0
# Narcolepsy
#              Narcolepsy
# genes
# MOG                 1.0
# HCRT                1.0
# PPAN-P2RY11         1.0
# PPAN                1.0
# EIF3G               1.0
# NPC1                1.0
# CTSH                1.0
# TNFSF4              1.0
# IFNAR1              1.0
# HLA-DRB1            1.0
# HLA-DQA2            1.0
# HLA-DQB1            1.0
# IL10RB              1.0
# ZNF365              1.0
# H2AC6               1.0
# DAD1                1.0
# P2RY11              1.0
# EGR2                1.0
# HFE                 1.0
# ADO                 1.0
# TNFSF18             1.0
# NeuroticDisorder
#          NeuroticDisorder
# genes
# DRD2                  1.0
# GRIK3                 1.0
# PRTFDC1               1.0
# ASXL3                 1.0
# TENM3                 1.0
# ...                   ...
# MSRA                  1.0
# RASSF1                1.0
# UBE3B                 1.0
# DYNAP                 1.0
# DLST                  1.0
#
# [83 rows x 1 columns]
# NMO
# NMO  doesn't have enough genes with high genetic scores.
# OCD
#          OCD
# genes
# SLC6A4   1.0
# DRD2     1.0
# GRIA1    1.0
# GRIK3    1.0
# TCF4     1.0
# ...      ...
# PLEKHO1  1.0
# DCP1B    1.0
# TOPAZ1   1.0
# RBKS     1.0
# PSMA4    1.0
#
# [192 rows x 1 columns]
# PartialEpilepsy
#          PartialEpilepsy
# genes
# GABRA1               1.0
# DEPDC5               1.0
# EFHC1                1.0
# GABRG2               1.0
# GRIN2A               1.0
# ...                  ...
# FGFR3                1.0
# OPLAH                1.0
# FAM131A              1.0
# CHRNA1               1.0
# STX1B                1.0
#
# [74 rows x 1 columns]
# PD
#            PD
# genes
# LRRK2     1.0
# SNCA      1.0
# PRKN      1.0
# ATP13A2   1.0
# PINK1     1.0
# ...       ...
# VNN2      1.0
# LRRN4     1.0
# FAM171A1  1.0
# PARP9     1.0
# OR6Q1     1.0
#
# [269 rows x 1 columns]
# PrD
# PrD  doesn't have enough genes with high genetic scores.
# ProgressiveSupranuclearPalsy
#               ProgressiveSupranuclearPalsy
# genes
# MAPT                                   1.0
# MOBP                                   1.0
# RUNX2                                  1.0
# SLC2A13                                1.0
# EIF2AK3                                1.0
# STX6                                   1.0
# SLCO1A2                                1.0
# IRF4                                   1.0
# OBSCN                                  1.0
# CD8B                                   1.0
# RPIA                                   1.0
# STH                                    1.0
# MR1                                    1.0
# IAPP                                   1.0
# DUSP10                                 1.0
# H3-4                                   1.0
# RMND5A                                 1.0
# RNF103-CHMP3                           1.0
# KIAA1614                               1.0
# TRIM17                                 1.0
# SUPT3H                                 1.0
# RestlessLeg
#          RestlessLeg
# genes
# MEIS1            1.0
# BTBD9            1.0
# CCDC148          1.0
# TOX3             1.0
# MYT1             1.0
# CCDC167          1.0
# ZNF804B          1.0
# RANBP17          1.0
# LMO1             1.0
# SEMA6D           1.0
# SLC40A1          1.0
# PRMT6            1.0
# C1D              1.0
# SETBP1           1.0
# ATP2C1           1.0
# DPH6             1.0
# CRBN             1.0
# SKOR1            1.0
# MICALL2          1.0
# UNCX             1.0
# MAP2K5           1.0
# NTNG1            1.0
# PRAC1            1.0
# DNAAF10          1.0
# PKP4             1.0
# PRAC2            1.0
# PNO1             1.0
# HOXB13           1.0
# TRNT1            1.0
# IL5RA            1.0
# TEX47            1.0
# WASHC3           1.0
# DCDC2C           1.0
# PMCH             1.0
# NPBWR2           1.0
# CMTR1            1.0
# LRRN1            1.0
# INTS1            1.0
# PPP3R1           1.0
# Schizophrenia
#          Schizophrenia
# genes
# DRD2               1.0
# DRD3               1.0
# ESR2               1.0
# GRIN2A             1.0
# RTN4R              1.0
# ...                ...
# VPS37B             1.0
# CEBPZOS            1.0
# NRIP2              1.0
# WDR17              1.0
# COX14              1.0
#
# [972 rows x 1 columns]
# TouretteSyndrome
#          TouretteSyndrome
# genes
# DRD2                  1.0
# SLITRK1               1.0
# IMMP2L                1.0
# TCF4                  1.0
# SORCS3                1.0
# ...                   ...
# DCP1B                 1.0
# TOPAZ1                1.0
# RBKS                  1.0
# PSMA4                 1.0
# PTP4A1                1.0
#
# [210 rows x 1 columns]
# UnipolarDepression
#          UnipolarDepression
# genes
# SORCS3                  1.0
# TCF4                    1.0
# OLFM4                   1.0
# NEGR1                   1.0
# GRM5                    1.0
# ...                     ...
# C6orf89                 1.0
# ZBTB34                  1.0
# VAMP2                   1.0
# TMEM107                 1.0
# ANKK1                   1.0
#
# [555 rows x 1 columns]
# AD
#            AD
# genes
# PSEN1     1.0
# APP       1.0
# PSEN2     1.0
# ACE       1.0
# UNC5C     1.0
# ...       ...
# MS4A2     1.0
# MAMSTR    1.0
# RFX3      1.0
# SERPINF1  1.0
# RRAS2     1.0
#
# [195 rows x 1 columns]
# ALS
#           ALS
# genes
# SOD1      1.0
# FUS       1.0
# ALS2      1.0
# SETX      1.0
# TARDBP    1.0
# ...       ...
# CAPN14    1.0
# DNAJC7    1.0
# DYNC1H1   1.0
# RIPK4     1.0
# HLA-DQB1  1.0
#
# [103 rows x 1 columns]
# AnorexiaNervosa
#          AnorexiaNervosa
# genes
# DRD2                 1.0
# TCF4                 1.0
# SORCS3               1.0
# CADM1                1.0
# CACNA1C              1.0
# ...                  ...
# FADS1                1.0
# IP6K2                1.0
# CRYBA1               1.0
# TOM1L2               1.0
# RORA                 1.0
#
# [179 rows x 1 columns]
# BipolarDisorder
#          BipolarDisorder
# genes
# DRD2                 1.0
# SCN2A                1.0
# GRIN2A               1.0
# SCN3A                1.0
# ALOX5AP              1.0
# ...                  ...
# PHETA2               1.0
# CRYBA1               1.0
# TMEM258              1.0
# TOM1L2               1.0
# GSDMA                1.0
#
# [399 rows x 1 columns]
# BrainAneurysm
#          BrainAneurysm
# genes
# THSD1              1.0
# EDNRA              1.0
# CDKN2B             1.0
# PDE3A              1.0
# STARD13            1.0
# RP1                1.0
# ATP2B1             1.0
# CDKN2A             1.0
# FHIT               1.0
# LINGO2             1.0
# FMO4               1.0
# MYEOV              1.0
# RNF144A            1.0
# TMOD1              1.0
# DRAM1              1.0
# DTHD1              1.0
# OLFML2A            1.0
# FBN1               1.0
# ZNF746             1.0
# SOX17              1.0
# SLC47A1            1.0
# DSCAM              1.0
# SLC24A3            1.0
# BET1L              1.0
# FGD6               1.0
# SLC2A14            1.0
# CHRNA5             1.0
# PLCE1              1.0
# POLR1F             1.0
# SCARF1             1.0
# VEGFC              1.0
# ANKRD44            1.0
# HYKK               1.0
# LRRC3              1.0
# SLC22A5            1.0
# CFDP1              1.0
# PAPPA              1.0
# SLC22A4            1.0
# MINK1              1.0
# FHL5               1.0
# PLCL1              1.0
# UFL1               1.0
# CCDC171            1.0
# HDAC4              1.0
# NR6A1              1.0
# PDCD1              1.0
# FAM240C            1.0
# MRTFB              1.0
# RIC8A              1.0
# PRDM2              1.0
# MTMR3              1.0
# KL                 1.0
# CNNM2              1.0
# NR2C1              1.0
# RBBP8              1.0
# PARN               1.0
# RFTN2              1.0
# FBN2               1.0
# HORMAD2            1.0
# KAZN               1.0
# CerebelarAmyloidAngiopathy
# CerebelarAmyloidAngiopathy  doesn't have enough genes with high genetic scores.
# EssentialTremor
#                  EssentialTremor
# genes
# TENM4                        1.0
# FUS                          1.0
# C19orf12                     1.0
# HARS1                        1.0
# NOTCH2NLC                    1.0
# STXBP1                       1.0
# SCN4A                        1.0
# TMEM67                       1.0
# DNAJC13                      1.0
# DRD3                         1.0
# STK32B                       1.0
# LINGO1                       1.0
# MPZ                          1.0
# FIG4                         1.0
# NAT2                         1.0
# GPR151                       1.0
# MT-ATP6                      1.0
# TGM4                         1.0
# CCDC183                      1.0
# DNHD1                        1.0
# ZNF528                       1.0
# LRRTM3                       1.0
# GBA1                         1.0
# DHX15                        1.0
# CACNA1H                      1.0
# ENSG00000260272              1.0
# GLI2                         1.0
# TBC1D24                      1.0
# ADGRV1                       1.0
# SYNE1                        1.0
# FAM228B                      1.0
# SH3D19                       1.0
# OR5K3                        1.0
# MMP10                        1.0
# MS4A14                       1.0
# PRSS48                       1.0
# GEMIN5                       1.0
# MYO6                         1.0
# OR5K4                        1.0
# OR6C1                        1.0
# PKD1L3                       1.0
# FrontotemporalDementia
#                  FrontotemporalDementia
# genes
# CHMP2B                              1.0
# GRN                                 1.0
# MAPT                                1.0
# PSEN1                               1.0
# SQSTM1                              1.0
# TMEM106B                            1.0
# TARDBP                              1.0
# TREM2                               1.0
# SETX                                1.0
# CYLD                                1.0
# CHRNB4                              1.0
# MEF2C                               1.0
# CSF1R                               1.0
# TBK1                                1.0
# GFRA2                               1.0
# CHRNA4                              1.0
# FUS                                 1.0
# HNRNPA2B1                           1.0
# CCNF                                1.0
# OPTN                                1.0
# ERBB4                               1.0
# DCTN1                               1.0
# ANG                                 1.0
# GLT8D1                              1.0
# RNASE4                              1.0
# ENSG00000259171                     1.0
# ABCA7                               1.0
# HLA-DRA                             1.0
# ARSA                                1.0
# VPS13C                              1.0
# TNK1                                1.0
# TM2D3                               1.0
# MIR4795                             1.0
# LRRK2                               1.0
# MARCHF4                             1.0
# IntracranialHemorrhage
#             IntracranialHemorrhage
# genes
# COL4A1                         1.0
# COL4A2                         1.0
# ACE                            1.0
# KAT6B                          1.0
# DLX5                           1.0
# ADGRG1                         1.0
# PWWP2B                         1.0
# APOC1                          1.0
# PMF1-BGLAP                     1.0
# PIRT                           1.0
# DPH1                           1.0
# ZBTB46                         1.0
# ICA1L                          1.0
# MEGF6                          1.0
# TMEM238L                       1.0
# PMF1                           1.0
# CARF                           1.0
# LBD
#          LBD
# genes
# SNCA     1.0
# GBA1     1.0
# SNCB     1.0
# APOE     1.0
# BIN1     1.0
# TMEM175  1.0
# IDUA     1.0
# ASH1L    1.0
# TOMM40   1.0
# GAK      1.0
# APOC1    1.0
# MajorDepressiveDisorder
#            MajorDepressiveDisorder
# genes
# DRD2                           1.0
# TCF4                           1.0
# LRFN5                          1.0
# NEGR1                          1.0
# TPH2                           1.0
# ...                            ...
# ZKSCAN4                        1.0
# FAM120AOS                      1.0
# CKB                            1.0
# CNTLN                          1.0
# NKAPL                          1.0
#
# [83 rows x 1 columns]
# MigraineDisorder
#          MigraineDisorder
# genes
# SCN1A                 1.0
# CACNA1A               1.0
# ATP1A2                1.0
# CALCB                 1.0
# CALCA                 1.0
# ...                   ...
# FHAD1                 1.0
# MKKS                  1.0
# PDGFD                 1.0
# B9D2                  1.0
# FOXP2                 1.0
#
# [119 rows x 1 columns]
# MigraineWithAura
#          MigraineWithAura
# genes
# CACNA1A               1.0
# SCN1A                 1.0
# ATP1A2                1.0
# NOTCH3                1.0
# PRRT2                 1.0
# IRAG1                 1.0
# FHL5                  1.0
# UFL1                  1.0
# STAT6                 1.0
# LRP1                  1.0
# DGUOK                 1.0
# LYVE1                 1.0
# MS
#           MS
# genes
# KEAP1    1.0
# IL2RA    1.0
# CD58     1.0
# IL7R     1.0
# ANKRD55  1.0
# ...      ...
# SART1    1.0
# PTPRK    1.0
# CAMK2G   1.0
# LRRC4C   1.0
# LRRC31   1.0
#
# [277 rows x 1 columns]
# NarcolepsyCataplexy
#              NarcolepsyCataplexy
# genes
# MOG                          1.0
# HCRT                         1.0
# PPAN-P2RY11                  1.0
# PPAN                         1.0
# EIF3G                        1.0
# NPC1                         1.0
# CTSH                         1.0
# TNFSF4                       1.0
# IFNAR1                       1.0
# HLA-DQA2                     1.0
# HLA-DRB1                     1.0
# HLA-DQB1                     1.0
# IL10RB                       1.0
# ZNF365                       1.0
# H2AC6                        1.0
# DAD1                         1.0
# P2RY11                       1.0
# EGR2                         1.0
# HFE                          1.0
# Narcolepsy
#              Narcolepsy
# genes
# MOG                 1.0
# HCRT                1.0
# PPAN-P2RY11         1.0
# PPAN                1.0
# EIF3G               1.0
# NPC1                1.0
# CTSH                1.0
# TNFSF4              1.0
# IFNAR1              1.0
# HLA-DRB1            1.0
# HLA-DQA2            1.0
# HLA-DQB1            1.0
# IL10RB              1.0
# ZNF365              1.0
# H2AC6               1.0
# DAD1                1.0
# P2RY11              1.0
# EGR2                1.0
# HFE                 1.0
# NeuroticDisorder
#          NeuroticDisorder
# genes
# DRD2                  1.0
# GRIK3                 1.0
# PRTFDC1               1.0
# ASXL3                 1.0
# TENM3                 1.0
# ...                   ...
# ORC4                  1.0
# CSF3R                 1.0
# ZC3H7B                1.0
# CCDC68                1.0
# PROX2                 1.0
#
# [71 rows x 1 columns]
# NMO
# NMO  doesn't have enough genes with high genetic scores.
# OCD
#         OCD
# genes
# SLC6A4  1.0
# DRD2    1.0
# GRIA1   1.0
# GRIK3   1.0
# TCF4    1.0
# ...     ...
# ITIH3   1.0
# FADS1   1.0
# CRYBA1  1.0
# TOM1L2  1.0
# RORA    1.0
#
# [147 rows x 1 columns]
# PartialEpilepsy
#          PartialEpilepsy
# genes
# GABRA1               1.0
# DEPDC5               1.0
# EFHC1                1.0
# GABRG2               1.0
# GRIN2A               1.0
# ...                  ...
# SLC33A1              1.0
# FGFR3                1.0
# OPLAH                1.0
# FAM131A              1.0
# CHRNA1               1.0
#
# [73 rows x 1 columns]
# PD
#           PD
# genes
# LRRK2    1.0
# SNCA     1.0
# PRKN     1.0
# ATP13A2  1.0
# PINK1    1.0
# ...      ...
# SLC35G6  1.0
# FDFT1    1.0
# WNT9B    1.0
# PRSS53   1.0
# BRIP1    1.0
#
# [220 rows x 1 columns]
# PrD
# PrD  doesn't have enough genes with high genetic scores.
# ProgressiveSupranuclearPalsy
#          ProgressiveSupranuclearPalsy
# genes
# MAPT                              1.0
# MOBP                              1.0
# RUNX2                             1.0
# SLC2A13                           1.0
# EIF2AK3                           1.0
# STX6                              1.0
# SLCO1A2                           1.0
# IRF4                              1.0
# OBSCN                             1.0
# CD8B                              1.0
# RPIA                              1.0
# STH                               1.0
# MR1                               1.0
# RestlessLeg
#          RestlessLeg
# genes
# MEIS1            1.0
# BTBD9            1.0
# CCDC148          1.0
# TOX3             1.0
# MYT1             1.0
# CCDC167          1.0
# ZNF804B          1.0
# RANBP17          1.0
# LMO1             1.0
# SEMA6D           1.0
# SLC40A1          1.0
# PRMT6            1.0
# C1D              1.0
# SETBP1           1.0
# ATP2C1           1.0
# DPH6             1.0
# CRBN             1.0
# SKOR1            1.0
# MICALL2          1.0
# UNCX             1.0
# MAP2K5           1.0
# NTNG1            1.0
# PRAC1            1.0
# DNAAF10          1.0
# PKP4             1.0
# PRAC2            1.0
# PNO1             1.0
# HOXB13           1.0
# TRNT1            1.0
# IL5RA            1.0
# TEX47            1.0
# WASHC3           1.0
# DCDC2C           1.0
# Schizophrenia
#          Schizophrenia
# genes
# DRD2               1.0
# DRD3               1.0
# ESR2               1.0
# GRIN2A             1.0
# RTN4R              1.0
# ...                ...
# HERC1              1.0
# ABCC10             1.0
# CRYBA1             1.0
# ZDHHC21            1.0
# TARS2              1.0
#
# [783 rows x 1 columns]
# TouretteSyndrome
#          TouretteSyndrome
# genes
# DRD2                  1.0
# SLITRK1               1.0
# IMMP2L                1.0
# TCF4                  1.0
# SORCS3                1.0
# ...                   ...
# FADS1                 1.0
# PLPP5                 1.0
# CRYBA1                1.0
# TOM1L2                1.0
# RORA                  1.0
#
# [158 rows x 1 columns]
# UnipolarDepression
#          UnipolarDepression
# genes
# SORCS3                  1.0
# TCF4                    1.0
# OLFM4                   1.0
# NEGR1                   1.0
# GRM5                    1.0
# ...                     ...
# POGZ                    1.0
# PLEKHO1                 1.0
# PGBD1                   1.0
# TOM1L2                  1.0
# RORA                    1.0
#
# [428 rows x 1 columns]
# AD
#          AD
# genes
# PSEN1   1.0
# APP     1.0
# PSEN2   1.0
# ACE     1.0
# UNC5C   1.0
# ...     ...
# PRSS53  1.0
# RELB    1.0
# MAF     1.0
# GRIK3   1.0
# CHRNA2  1.0
#
# [154 rows x 1 columns]
# ALS
#         ALS
# genes
# SOD1    1.0
# FUS     1.0
# ALS2    1.0
# SETX    1.0
# TARDBP  1.0
# ...     ...
# IDE     1.0
# TNIP1   1.0
# KIFAP3  1.0
# IQCF5   1.0
# SARM1   1.0
#
# [90 rows x 1 columns]
# AnorexiaNervosa
#             AnorexiaNervosa
# genes
# DRD2                    1.0
# TCF4                    1.0
# SORCS3                  1.0
# CADM1                   1.0
# CACNA1C                 1.0
# ...                     ...
# RFTN2                   1.0
# ATP2A2                  1.0
# HSPE1-MOB4              1.0
# GATAD2A                 1.0
# MOB4                    1.0
#
# [141 rows x 1 columns]
# BipolarDisorder
#          BipolarDisorder
# genes
# DRD2                 1.0
# SCN2A                1.0
# GRIN2A               1.0
# ALOX5AP              1.0
# CACNA1C              1.0
# ...                  ...
# CSF3R                1.0
# PRORP                1.0
# ANKRD36              1.0
# NUF2                 1.0
# SKOR1                1.0
#
# [308 rows x 1 columns]
# BrainAneurysm
#          BrainAneurysm
# genes
# THSD1              1.0
# EDNRA              1.0
# CDKN2B             1.0
# PDE3A              1.0
# STARD13            1.0
# RP1                1.0
# ATP2B1             1.0
# CDKN2A             1.0
# FHIT               1.0
# LINGO2             1.0
# FMO4               1.0
# MYEOV              1.0
# RNF144A            1.0
# TMOD1              1.0
# DRAM1              1.0
# DTHD1              1.0
# OLFML2A            1.0
# FBN1               1.0
# ZNF746             1.0
# SOX17              1.0
# SLC47A1            1.0
# DSCAM              1.0
# SLC24A3            1.0
# BET1L              1.0
# FGD6               1.0
# SLC2A14            1.0
# CHRNA5             1.0
# PLCE1              1.0
# POLR1F             1.0
# SCARF1             1.0
# VEGFC              1.0
# ANKRD44            1.0
# HYKK               1.0
# LRRC3              1.0
# SLC22A5            1.0
# CFDP1              1.0
# PAPPA              1.0
# SLC22A4            1.0
# MINK1              1.0
# FHL5               1.0
# PLCL1              1.0
# UFL1               1.0
# CCDC171            1.0
# HDAC4              1.0
# NR6A1              1.0
# PDCD1              1.0
# FAM240C            1.0
# MRTFB              1.0
# RIC8A              1.0
# PRDM2              1.0
# MTMR3              1.0
# KL                 1.0
# CNNM2              1.0
# NR2C1              1.0
# CerebelarAmyloidAngiopathy
# CerebelarAmyloidAngiopathy  doesn't have enough genes with high genetic scores.
# EssentialTremor
#            EssentialTremor
# genes
# TENM4                  1.0
# FUS                    1.0
# C19orf12               1.0
# HARS1                  1.0
# NOTCH2NLC              1.0
# STXBP1                 1.0
# SCN4A                  1.0
# TMEM67                 1.0
# DNAJC13                1.0
# DRD3                   1.0
# STK32B                 1.0
# LINGO1                 1.0
# MPZ                    1.0
# FIG4                   1.0
# NAT2                   1.0
# GPR151                 1.0
# MT-ATP6                1.0
# TGM4                   1.0
# CCDC183                1.0
# DNHD1                  1.0
# ZNF528                 1.0
# LRRTM3                 1.0
# GBA1                   1.0
# DHX15                  1.0
# FrontotemporalDementia
#                  FrontotemporalDementia
# genes
# CHMP2B                              1.0
# GRN                                 1.0
# MAPT                                1.0
# PSEN1                               1.0
# SQSTM1                              1.0
# TMEM106B                            1.0
# TARDBP                              1.0
# TREM2                               1.0
# SETX                                1.0
# CYLD                                1.0
# CHRNB4                              1.0
# MEF2C                               1.0
# CSF1R                               1.0
# TBK1                                1.0
# GFRA2                               1.0
# CHRNA4                              1.0
# FUS                                 1.0
# HNRNPA2B1                           1.0
# CCNF                                1.0
# OPTN                                1.0
# ERBB4                               1.0
# DCTN1                               1.0
# ANG                                 1.0
# GLT8D1                              1.0
# RNASE4                              1.0
# ENSG00000259171                     1.0
# ABCA7                               1.0
# HLA-DRA                             1.0
# IntracranialHemorrhage
#             IntracranialHemorrhage
# genes
# COL4A1                         1.0
# COL4A2                         1.0
# ACE                            1.0
# KAT6B                          1.0
# DLX5                           1.0
# ADGRG1                         1.0
# PWWP2B                         1.0
# APOC1                          1.0
# PMF1-BGLAP                     1.0
# PIRT                           1.0
# DPH1                           1.0
# ZBTB46                         1.0
# ICA1L                          1.0
# MEGF6                          1.0
# TMEM238L                       1.0
# LBD
# LBD  doesn't have enough genes with high genetic scores.
# MajorDepressiveDisorder
#          MajorDepressiveDisorder
# genes
# DRD2                         1.0
# TCF4                         1.0
# LRFN5                        1.0
# NEGR1                        1.0
# TPH2                         1.0
# ...                          ...
# ZSCAN26                      1.0
# OR2B2                        1.0
# NCOA5                        1.0
# METTL15                      1.0
# PIK3C3                       1.0
#
# [66 rows x 1 columns]
# MigraineDisorder
#           MigraineDisorder
# genes
# SCN1A                  1.0
# CACNA1A                1.0
# ATP1A2                 1.0
# CALCB                  1.0
# CALCA                  1.0
# ...                    ...
# NCBP3                  1.0
# EML1                   1.0
# FSHB                   1.0
# ANKRD36C               1.0
# LYVE1                  1.0
#
# [99 rows x 1 columns]
# MigraineWithAura
#          MigraineWithAura
# genes
# CACNA1A               1.0
# SCN1A                 1.0
# ATP1A2                1.0
# NOTCH3                1.0
# PRRT2                 1.0
# IRAG1                 1.0
# FHL5                  1.0
# UFL1                  1.0
# STAT6                 1.0
# LRP1                  1.0
# DGUOK                 1.0
# MS
#           MS
# genes
# KEAP1    1.0
# IL2RA    1.0
# CD58     1.0
# IL7R     1.0
# ANKRD55  1.0
# ...      ...
# SMCR8    1.0
# PTGER4   1.0
# CCNE2    1.0
# TOP3A    1.0
# INTS8    1.0
#
# [237 rows x 1 columns]
# NarcolepsyCataplexy
#              NarcolepsyCataplexy
# genes
# MOG                          1.0
# HCRT                         1.0
# PPAN-P2RY11                  1.0
# PPAN                         1.0
# EIF3G                        1.0
# NPC1                         1.0
# CTSH                         1.0
# TNFSF4                       1.0
# IFNAR1                       1.0
# HLA-DQA2                     1.0
# HLA-DRB1                     1.0
# HLA-DQB1                     1.0
# IL10RB                       1.0
# ZNF365                       1.0
# H2AC6                        1.0
# DAD1                         1.0
# P2RY11                       1.0
# Narcolepsy
#              Narcolepsy
# genes
# MOG                 1.0
# HCRT                1.0
# PPAN-P2RY11         1.0
# PPAN                1.0
# EIF3G               1.0
# NPC1                1.0
# CTSH                1.0
# TNFSF4              1.0
# IFNAR1              1.0
# HLA-DRB1            1.0
# HLA-DQA2            1.0
# HLA-DQB1            1.0
# IL10RB              1.0
# ZNF365              1.0
# H2AC6               1.0
# DAD1                1.0
# P2RY11              1.0
# NeuroticDisorder
#            NeuroticDisorder
# genes
# DRD2                    1.0
# PRTFDC1                 1.0
# ASXL3                   1.0
# TENM3                   1.0
# TLL1                    1.0
# GRM5                    1.0
# PAX6                    1.0
# PTCH1                   1.0
# XKR6                    1.0
# CELF4                   1.0
# ARPP21                  1.0
# GRM3                    1.0
# DCC                     1.0
# CTTNBP2                 1.0
# GLIS3                   1.0
# BAIAP2                  1.0
# ARNTL                   1.0
# CCSER1                  1.0
# ZNF804A                 1.0
# TMEM106B                1.0
# TLR4                    1.0
# BARHL2                  1.0
# BBX                     1.0
# GRM8                    1.0
# LINGO1                  1.0
# ZNF184                  1.0
# ZDHHC14                 1.0
# CSMD1                   1.0
# SOX6                    1.0
# PLCL2                   1.0
# MYCN                    1.0
# PRKN                    1.0
# FAM120A                 1.0
# NR4A2                   1.0
# SIPA1L1                 1.0
# DNM3                    1.0
# FAM120AOS               1.0
# SOX5                    1.0
# MYO1H                   1.0
# ATF4                    1.0
# HIVEP1                  1.0
# FBXL17                  1.0
# SLC7A11                 1.0
# MAD1L1                  1.0
# ELAVL2                  1.0
# FANCL                   1.0
# NOS1                    1.0
# PAFAH1B1                1.0
# TNXB                    1.0
# ACVR2A                  1.0
# MAPT                    1.0
# PCLO                    1.0
# PRAG1                   1.0
# ZNF391                  1.0
# STAG1                   1.0
# MED24                   1.0
# YLPM1                   1.0
# AATK                    1.0
# KAZN                    1.0
# MBD5                    1.0
# NMO
# NMO  doesn't have enough genes with high genetic scores.
# OCD
#             OCD
# genes
# SLC6A4      1.0
# DRD2        1.0
# GRIA1       1.0
# TCF4        1.0
# SORCS3      1.0
# ...         ...
# RFTN2       1.0
# PIK3C3      1.0
# HSPE1-MOB4  1.0
# MOB4        1.0
# HK3         1.0
#
# [116 rows x 1 columns]
# PartialEpilepsy
#          PartialEpilepsy
# genes
# GABRA1               1.0
# DEPDC5               1.0
# EFHC1                1.0
# GABRG2               1.0
# GRIN2A               1.0
# ...                  ...
# ZEB2                 1.0
# TBC1D32              1.0
# PRIMA1               1.0
# SLC33A1              1.0
# FGFR3                1.0
#
# [70 rows x 1 columns]
# PD
#           PD
# genes
# LRRK2    1.0
# SNCA     1.0
# PRKN     1.0
# ATP13A2  1.0
# PINK1    1.0
# ...      ...
# LRRC37A  1.0
# ITGA2B   1.0
# UGT2B10  1.0
# SNX20    1.0
# BIN3     1.0
#
# [188 rows x 1 columns]
# PrD
# PrD  doesn't have enough genes with high genetic scores.
# ProgressiveSupranuclearPalsy
# ProgressiveSupranuclearPalsy  doesn't have enough genes with high genetic scores.
# RestlessLeg
#          RestlessLeg
# genes
# MEIS1            1.0
# BTBD9            1.0
# CCDC148          1.0
# TOX3             1.0
# MYT1             1.0
# CCDC167          1.0
# ZNF804B          1.0
# RANBP17          1.0
# LMO1             1.0
# SEMA6D           1.0
# SLC40A1          1.0
# PRMT6            1.0
# C1D              1.0
# SETBP1           1.0
# ATP2C1           1.0
# DPH6             1.0
# CRBN             1.0
# SKOR1            1.0
# MICALL2          1.0
# UNCX             1.0
# MAP2K5           1.0
# NTNG1            1.0
# PRAC1            1.0
# DNAAF10          1.0
# PKP4             1.0
# PRAC2            1.0
# PNO1             1.0
# HOXB13           1.0
# Schizophrenia
#          Schizophrenia
# genes
# DRD2               1.0
# DRD3               1.0
# ESR2               1.0
# GRIN2A             1.0
# RTN4R              1.0
# ...                ...
# ANKRD36            1.0
# TLE1               1.0
# PANX3              1.0
# GLB1L3             1.0
# CTNND1             1.0
#
# [651 rows x 1 columns]
# TouretteSyndrome
#             TouretteSyndrome
# genes
# DRD2                     1.0
# SLITRK1                  1.0
# IMMP2L                   1.0
# TCF4                     1.0
# SORCS3                   1.0
# ...                      ...
# RFLNA                    1.0
# RFTN2                    1.0
# HSPE1-MOB4               1.0
# MOB4                     1.0
# EYS                      1.0
#
# [123 rows x 1 columns]
# UnipolarDepression
#          UnipolarDepression
# genes
# SORCS3                  1.0
# TCF4                    1.0
# OLFM4                   1.0
# NEGR1                   1.0
# GRM5                    1.0
# ...                     ...
# HLA-B                   1.0
# POU5F2                  1.0
# MOB4                    1.0
# ZSCAN12                 1.0
# ADAMTS9                 1.0
#
# [357 rows x 1 columns]
# AD
#          AD
# genes
# PSEN1   1.0
# APP     1.0
# PSEN2   1.0
# ACE     1.0
# UNC5C   1.0
# ...     ...
# SCIMP   1.0
# OARD1   1.0
# PRIM2   1.0
# ADGRL1  1.0
# TNRC6A  1.0
#
# [129 rows x 1 columns]
# ALS
#         ALS
# genes
# SOD1    1.0
# FUS     1.0
# ALS2    1.0
# SETX    1.0
# TARDBP  1.0
# ...     ...
# EWSR1   1.0
# HHEX    1.0
# SS18L1  1.0
# NUDT12  1.0
# TMEM97  1.0
#
# [80 rows x 1 columns]
# AnorexiaNervosa
#          AnorexiaNervosa
# genes
# DRD2                 1.0
# TCF4                 1.0
# SORCS3               1.0
# CADM1                1.0
# CACNA1C              1.0
# ...                  ...
# SPHKAP               1.0
# CHRNA5               1.0
# ERLEC1               1.0
# C3orf49              1.0
# PTN                  1.0
#
# [113 rows x 1 columns]
# BipolarDisorder
#          BipolarDisorder
# genes
# DRD2                 1.0
# SCN2A                1.0
# GRIN2A               1.0
# ALOX5AP              1.0
# CACNA1C              1.0
# ...                  ...
# C3orf49              1.0
# ALG14                1.0
# BAG5                 1.0
# PTN                  1.0
# MRPL33               1.0
#
# [252 rows x 1 columns]
# BrainAneurysm
#          BrainAneurysm
# genes
# THSD1              1.0
# EDNRA              1.0
# CDKN2B             1.0
# PDE3A              1.0
# STARD13            1.0
# RP1                1.0
# ATP2B1             1.0
# CDKN2A             1.0
# FHIT               1.0
# LINGO2             1.0
# FMO4               1.0
# MYEOV              1.0
# RNF144A            1.0
# TMOD1              1.0
# DRAM1              1.0
# DTHD1              1.0
# OLFML2A            1.0
# FBN1               1.0
# ZNF746             1.0
# SOX17              1.0
# SLC47A1            1.0
# DSCAM              1.0
# SLC24A3            1.0
# BET1L              1.0
# FGD6               1.0
# SLC2A14            1.0
# CHRNA5             1.0
# PLCE1              1.0
# POLR1F             1.0
# SCARF1             1.0
# VEGFC              1.0
# ANKRD44            1.0
# HYKK               1.0
# LRRC3              1.0
# SLC22A5            1.0
# CFDP1              1.0
# PAPPA              1.0
# SLC22A4            1.0
# MINK1              1.0
# FHL5               1.0
# PLCL1              1.0
# UFL1               1.0
# CCDC171            1.0
# HDAC4              1.0
# NR6A1              1.0
# PDCD1              1.0
# FAM240C            1.0
# CerebelarAmyloidAngiopathy
# CerebelarAmyloidAngiopathy  doesn't have enough genes with high genetic scores.
# EssentialTremor
#            EssentialTremor
# genes
# TENM4                  1.0
# FUS                    1.0
# C19orf12               1.0
# HARS1                  1.0
# NOTCH2NLC              1.0
# STXBP1                 1.0
# SCN4A                  1.0
# TMEM67                 1.0
# DNAJC13                1.0
# DRD3                   1.0
# STK32B                 1.0
# LINGO1                 1.0
# MPZ                    1.0
# FIG4                   1.0
# NAT2                   1.0
# GPR151                 1.0
# MT-ATP6                1.0
# TGM4                   1.0
# CCDC183                1.0
# DNHD1                  1.0
# ZNF528                 1.0
# LRRTM3                 1.0
# GBA1                   1.0
# FrontotemporalDementia
#                  FrontotemporalDementia
# genes
# CHMP2B                              1.0
# GRN                                 1.0
# MAPT                                1.0
# PSEN1                               1.0
# SQSTM1                              1.0
# TMEM106B                            1.0
# TARDBP                              1.0
# TREM2                               1.0
# SETX                                1.0
# CYLD                                1.0
# CHRNB4                              1.0
# MEF2C                               1.0
# CSF1R                               1.0
# TBK1                                1.0
# GFRA2                               1.0
# CHRNA4                              1.0
# FUS                                 1.0
# HNRNPA2B1                           1.0
# CCNF                                1.0
# OPTN                                1.0
# ERBB4                               1.0
# DCTN1                               1.0
# ANG                                 1.0
# GLT8D1                              1.0
# RNASE4                              1.0
# ENSG00000259171                     1.0
# ABCA7                               1.0
# HLA-DRA                             1.0
# IntracranialHemorrhage
#             IntracranialHemorrhage
# genes
# COL4A1                         1.0
# COL4A2                         1.0
# ACE                            1.0
# KAT6B                          1.0
# DLX5                           1.0
# ADGRG1                         1.0
# PWWP2B                         1.0
# APOC1                          1.0
# PMF1-BGLAP                     1.0
# PIRT                           1.0
# DPH1                           1.0
# ZBTB46                         1.0
# LBD
# LBD  doesn't have enough genes with high genetic scores.
# MajorDepressiveDisorder
#           MajorDepressiveDisorder
# genes
# DRD2                          1.0
# TCF4                          1.0
# LRFN5                         1.0
# NEGR1                         1.0
# TPH2                          1.0
# DCC                           1.0
# CHRM2                         1.0
# VRK2                          1.0
# SORCS3                        1.0
# GRM5                          1.0
# KCNG2                         1.0
# ACTL8                         1.0
# ESR2                          1.0
# MEGF11                        1.0
# FHIT                          1.0
# AGBL4                         1.0
# PCLO                          1.0
# SEMA6D                        1.0
# NCAM1                         1.0
# CELF4                         1.0
# WNT7B                         1.0
# TMEM106B                      1.0
# ERBB4                         1.0
# KLF7                          1.0
# FOXP2                         1.0
# PDE4B                         1.0
# B3GLCT                        1.0
# FES                           1.0
# AREL1                         1.0
# METTL9                        1.0
# RBMS3                         1.0
# FAM120A                       1.0
# PPARA                         1.0
# ACVR1B                        1.0
# CCDC68                        1.0
# ZSCAN31                       1.0
# CTTNBP2                       1.0
# AMPH                          1.0
# HS6ST3                        1.0
# ASTN2                         1.0
# FAM172A                       1.0
# ERCC4                         1.0
# ELAVL4                        1.0
# EYS                           1.0
# BTN3A2                        1.0
# TRAF3                         1.0
# NRDC                          1.0
# CNNM2                         1.0
# RSRC1                         1.0
# DAGLA                         1.0
# TUSC1                         1.0
# SLC12A5                       1.0
# ZCCHC7                        1.0
# MARK3                         1.0
# GRIK3                         1.0
# HIVEP2                        1.0
# MigraineDisorder
#          MigraineDisorder
# genes
# SCN1A                 1.0
# CACNA1A               1.0
# ATP1A2                1.0
# CALCB                 1.0
# CALCA                 1.0
# ...                   ...
# ZMYND8                1.0
# CARF                  1.0
# FGF23                 1.0
# SDR9C7                1.0
# MRPS6                 1.0
#
# [81 rows x 1 columns]
# MigraineWithAura
# MigraineWithAura  doesn't have enough genes with high genetic scores.
# MS
#           MS
# genes
# IL2RA    1.0
# CD58     1.0
# IL7R     1.0
# ANKRD55  1.0
# CD86     1.0
# ...      ...
# DLEU7    1.0
# FBXO48   1.0
# ADO      1.0
# ILDR1    1.0
# EAF2     1.0
#
# [204 rows x 1 columns]
# NarcolepsyCataplexy
#              NarcolepsyCataplexy
# genes
# MOG                          1.0
# HCRT                         1.0
# PPAN-P2RY11                  1.0
# PPAN                         1.0
# EIF3G                        1.0
# NPC1                         1.0
# CTSH                         1.0
# TNFSF4                       1.0
# IFNAR1                       1.0
# HLA-DQA2                     1.0
# HLA-DRB1                     1.0
# HLA-DQB1                     1.0
# IL10RB                       1.0
# ZNF365                       1.0
# Narcolepsy
#              Narcolepsy
# genes
# MOG                 1.0
# HCRT                1.0
# PPAN-P2RY11         1.0
# PPAN                1.0
# EIF3G               1.0
# NPC1                1.0
# CTSH                1.0
# TNFSF4              1.0
# IFNAR1              1.0
# HLA-DRB1            1.0
# HLA-DQA2            1.0
# HLA-DQB1            1.0
# IL10RB              1.0
# ZNF365              1.0
# NeuroticDisorder
#            NeuroticDisorder
# genes
# DRD2                    1.0
# PRTFDC1                 1.0
# ASXL3                   1.0
# TENM3                   1.0
# TLL1                    1.0
# GRM5                    1.0
# PAX6                    1.0
# PTCH1                   1.0
# XKR6                    1.0
# CELF4                   1.0
# ARPP21                  1.0
# GRM3                    1.0
# DCC                     1.0
# CTTNBP2                 1.0
# GLIS3                   1.0
# BAIAP2                  1.0
# ARNTL                   1.0
# CCSER1                  1.0
# ZNF804A                 1.0
# TMEM106B                1.0
# TLR4                    1.0
# BARHL2                  1.0
# BBX                     1.0
# GRM8                    1.0
# LINGO1                  1.0
# ZNF184                  1.0
# ZDHHC14                 1.0
# CSMD1                   1.0
# SOX6                    1.0
# PLCL2                   1.0
# MYCN                    1.0
# PRKN                    1.0
# FAM120A                 1.0
# NR4A2                   1.0
# SIPA1L1                 1.0
# DNM3                    1.0
# FAM120AOS               1.0
# SOX5                    1.0
# MYO1H                   1.0
# ATF4                    1.0
# HIVEP1                  1.0
# FBXL17                  1.0
# SLC7A11                 1.0
# MAD1L1                  1.0
# ELAVL2                  1.0
# FANCL                   1.0
# NOS1                    1.0
# PAFAH1B1                1.0
# TNXB                    1.0
# ACVR2A                  1.0
# PCLO                    1.0
# NMO
# NMO  doesn't have enough genes with high genetic scores.
# OCD
#          OCD
# genes
# SLC6A4   1.0
# DRD2     1.0
# TCF4     1.0
# SORCS3   1.0
# GRIN2A   1.0
# ...      ...
# PCMTD1   1.0
# BRINP2   1.0
# C3orf49  1.0
# PTN      1.0
# NMUR2    1.0
#
# [93 rows x 1 columns]
# PartialEpilepsy
# ...
# NeuroticDisorder  doesn't have enough genes with high genetic scores.
# NMO
# NMO  doesn't have enough genes with high genetic scores.
# OCD
# OCD  doesn't have enough genes with high genetic scores.
# PartialEpilepsy
#                  PartialEpilepsy
# genes
# GABRA1                       1.0
# DEPDC5                       1.0
# EFHC1                        1.0
# GABRG2                       1.0
# GRIN2A                       1.0
# RELN                         1.0
# CLCN2                        1.0
# GABRB3                       1.0
# CACNA1H                      1.0
# SCN9A                        1.0
# CACNB4                       1.0
# CILK1                        1.0
# CPA6                         1.0
# KCNT1                        1.0
# GABRD                        1.0
# LGI1                         1.0
# NPRL2                        1.0
# SZT2                         1.0
# ENSG00000285404              1.0
# SPTAN1                       1.0
# CNTNAP2                      1.0
# KCNQ3                        1.0
# RBFOX1                       1.0
# CHD2                         1.0
# GAL                          1.0
# PD
#           PD
# genes
# LRRK2    1.0
# SNCA     1.0
# PRKN     1.0
# ATP13A2  1.0
# PINK1    1.0
# PARK7    1.0
# FBXO7    1.0
# VPS35    1.0
# GIGYF2   1.0
# PLA2G6   1.0
# GBA1     1.0
# VPS13C   1.0
# MAPT     1.0
# EIF4G1   1.0
# BRCA2    1.0
# BRCA1    1.0
# RIT2     1.0
# BST1     1.0
# SH3GL2   1.0
# PrD
# PrD  doesn't have enough genes with high genetic scores.
# ProgressiveSupranuclearPalsy
# ProgressiveSupranuclearPalsy  doesn't have enough genes with high genetic scores.
# RestlessLeg
# RestlessLeg  doesn't have enough genes with high genetic scores.
# Schizophrenia
#                  Schizophrenia
# genes
# DRD2                       1.0
# RTN4R                      1.0
# GRM3                       1.0
# TCF4                       1.0
# GRIA1                      1.0
# CACNA1I                    1.0
# ZNF804A                    1.0
# SLC39A8                    1.0
# RGS6                       1.0
# GPM6A                      1.0
# SNAP91                     1.0
# BCL11B                     1.0
# MMP16                      1.0
# SORCS3                     1.0
# TSNARE1                    1.0
# ZSWIM6                     1.0
# IGSF9B                     1.0
# CACNA1C                    1.0
# GALNT10                    1.0
# CACNB2                     1.0
# IMMP2L                     1.0
# SPATS2L                    1.0
# PRODH                      1.0
# VRK2                       1.0
# DPYD                       1.0
# CNTN4                      1.0
# MRTFA                      1.0
# SNX19                      1.0
# KCNG2                      1.0
# BRINP2                     1.0
# BCL11A                     1.0
# ZNF536                     1.0
# ENSG00000283809            1.0
# TRANK1                     1.0
# POM121L2                   1.0
# PRKD1                      1.0
# TouretteSyndrome
# TouretteSyndrome  doesn't have enough genes with high genetic scores.
# UnipolarDepression
#           UnipolarDepression
# genes
# SORCS3                   1.0
# TCF4                     1.0
# OLFM4                    1.0
# NEGR1                    1.0
# GRM5                     1.0
# MEF2C                    1.0
# CELF4                    1.0
# DCC                      1.0
# SHISA9                   1.0
# TMEM106B                 1.0
# DRD2                     1.0
# LIN28B                   1.0
# AD
# AD  doesn't have enough genes with high genetic scores.
# ALS
#                  ALS
# genes
# SOD1             1.0
# FUS              1.0
# ALS2             1.0
# SETX             1.0
# TARDBP           1.0
# UBQLN2           1.0
# TBK1             1.0
# DCTN1            1.0
# VCP              1.0
# ANG              1.0
# SPG11            1.0
# SIGMAR1          1.0
# ENSG00000259171  1.0
# RNASE4           1.0
# SQSTM1           1.0
# PFN1             1.0
# FIG4             1.0
# OPTN             1.0
# TUBA4A           1.0
# VAPB             1.0
# AnorexiaNervosa
# AnorexiaNervosa  doesn't have enough genes with high genetic scores.
# BipolarDisorder
# BipolarDisorder  doesn't have enough genes with high genetic scores.
# BrainAneurysm
# BrainAneurysm  doesn't have enough genes with high genetic scores.
# CerebelarAmyloidAngiopathy
# CerebelarAmyloidAngiopathy  doesn't have enough genes with high genetic scores.
# EssentialTremor
# EssentialTremor  doesn't have enough genes with high genetic scores.
# FrontotemporalDementia
# FrontotemporalDementia  doesn't have enough genes with high genetic scores.
# IntracranialHemorrhage
# IntracranialHemorrhage  doesn't have enough genes with high genetic scores.
# LBD
# LBD  doesn't have enough genes with high genetic scores.
# MajorDepressiveDisorder
# MajorDepressiveDisorder  doesn't have enough genes with high genetic scores.
# MigraineDisorder
# MigraineDisorder  doesn't have enough genes with high genetic scores.
# MigraineWithAura
# MigraineWithAura  doesn't have enough genes with high genetic scores.
# MS
# MS  doesn't have enough genes with high genetic scores.
# NarcolepsyCataplexy
# NarcolepsyCataplexy  doesn't have enough genes with high genetic scores.
# Narcolepsy
# Narcolepsy  doesn't have enough genes with high genetic scores.
# NeuroticDisorder
# NeuroticDisorder  doesn't have enough genes with high genetic scores.
# NMO
# NMO  doesn't have enough genes with high genetic scores.
# OCD
# OCD  doesn't have enough genes with high genetic scores.
# PartialEpilepsy
#                  PartialEpilepsy
# genes
# GABRA1                       1.0
# DEPDC5                       1.0
# EFHC1                        1.0
# GABRG2                       1.0
# GRIN2A                       1.0
# RELN                         1.0
# CLCN2                        1.0
# GABRB3                       1.0
# CACNA1H                      1.0
# SCN9A                        1.0
# CILK1                        1.0
# SZT2                         1.0
# ENSG00000285404              1.0
# SPTAN1                       1.0
# CNTNAP2                      1.0
# PD
#           PD
# genes
# LRRK2    1.0
# SNCA     1.0
# PRKN     1.0
# ATP13A2  1.0
# PINK1    1.0
# PARK7    1.0
# FBXO7    1.0
# VPS35    1.0
# GIGYF2   1.0
# PLA2G6   1.0
# GBA1     1.0
# BRCA2    1.0
# BRCA1    1.0
# RIT2     1.0
# PrD
# PrD  doesn't have enough genes with high genetic scores.
# ProgressiveSupranuclearPalsy
# ProgressiveSupranuclearPalsy  doesn't have enough genes with high genetic scores.
# RestlessLeg
# RestlessLeg  doesn't have enough genes with high genetic scores.
# Schizophrenia
#          Schizophrenia
# genes
# RTN4R              1.0
# GRM3               1.0
# TCF4               1.0
# CACNA1I            1.0
# ZNF804A            1.0
# SLC39A8            1.0
# RGS6               1.0
# GPM6A              1.0
# SNAP91             1.0
# BCL11B             1.0
# MMP16              1.0
# SORCS3             1.0
# TSNARE1            1.0
# ZSWIM6             1.0
# IGSF9B             1.0
# TouretteSyndrome
# TouretteSyndrome  doesn't have enough genes with high genetic scores.
# UnipolarDepression
# UnipolarDepression  doesn't have enough genes with high genetic scores.
# AD
# AD  doesn't have enough genes with high genetic scores.
# ALS
#          ALS
# genes
# SOD1     1.0
# FUS      1.0
# ALS2     1.0
# SETX     1.0
# TARDBP   1.0
# UBQLN2   1.0
# TBK1     1.0
# DCTN1    1.0
# VCP      1.0
# ANG      1.0
# SPG11    1.0
# SIGMAR1  1.0
# AnorexiaNervosa
# AnorexiaNervosa  doesn't have enough genes with high genetic scores.
# BipolarDisorder
# BipolarDisorder  doesn't have enough genes with high genetic scores.
# BrainAneurysm
# BrainAneurysm  doesn't have enough genes with high genetic scores.
# CerebelarAmyloidAngiopathy
# CerebelarAmyloidAngiopathy  doesn't have enough genes with high genetic scores.
# EssentialTremor
# EssentialTremor  doesn't have enough genes with high genetic scores.
# FrontotemporalDementia
# FrontotemporalDementia  doesn't have enough genes with high genetic scores.
# IntracranialHemorrhage
# IntracranialHemorrhage  doesn't have enough genes with high genetic scores.
# LBD
# LBD  doesn't have enough genes with high genetic scores.
# MajorDepressiveDisorder
# MajorDepressiveDisorder  doesn't have enough genes with high genetic scores.
# MigraineDisorder
# MigraineDisorder  doesn't have enough genes with high genetic scores.
# MigraineWithAura
# MigraineWithAura  doesn't have enough genes with high genetic scores.
# MS
# MS  doesn't have enough genes with high genetic scores.
# NarcolepsyCataplexy
# NarcolepsyCataplexy  doesn't have enough genes with high genetic scores.
# Narcolepsy
# Narcolepsy  doesn't have enough genes with high genetic scores.
# NeuroticDisorder
# NeuroticDisorder  doesn't have enough genes with high genetic scores.
# NMO
# NMO  doesn't have enough genes with high genetic scores.
# OCD
# OCD  doesn't have enough genes with high genetic scores.
# PartialEpilepsy
# PartialEpilepsy  doesn't have enough genes with high genetic scores.
# PD
# PD  doesn't have enough genes with high genetic scores.
# PrD
# PrD  doesn't have enough genes with high genetic scores.
# ProgressiveSupranuclearPalsy
# ProgressiveSupranuclearPalsy  doesn't have enough genes with high genetic scores.
# RestlessLeg
# RestlessLeg  doesn't have enough genes with high genetic scores.
# Schizophrenia
# Schizophrenia  doesn't have enough genes with high genetic scores.
# TouretteSyndrome
# TouretteSyndrome  doesn't have enough genes with high genetic scores.
# UnipolarDepression
# UnipolarDepression  doesn't have enough genes with high genetic scores.
# AD
# AD  doesn't have enough genes with high genetic scores.
# ALS
# ALS  doesn't have enough genes with high genetic scores.
# AnorexiaNervosa
# AnorexiaNervosa  doesn't have enough genes with high genetic scores.
# BipolarDisorder
# BipolarDisorder  doesn't have enough genes with high genetic scores.
# BrainAneurysm
# BrainAneurysm  doesn't have enough genes with high genetic scores.
# CerebelarAmyloidAngiopathy
# CerebelarAmyloidAngiopathy  doesn't have enough genes with high genetic scores.
# EssentialTremor
# EssentialTremor  doesn't have enough genes with high genetic scores.
# FrontotemporalDementia
# FrontotemporalDementia  doesn't have enough genes with high genetic scores.
# c:\Users\melis\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:25: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ALS_x'} in the result is deprecated and will raise a MergeError in a future version.
# IntracranialHemorrhage
# IntracranialHemorrhage  doesn't have enough genes with high genetic scores.
# LBD
# LBD  doesn't have enough genes with high genetic scores.
# MajorDepressiveDisorder
# MajorDepressiveDisorder  doesn't have enough genes with high genetic scores.
# MigraineDisorder
# MigraineDisorder  doesn't have enough genes with high genetic scores.
# MigraineWithAura
# MigraineWithAura  doesn't have enough genes with high genetic scores.
# MS
# MS  doesn't have enough genes with high genetic scores.
# NarcolepsyCataplexy
# NarcolepsyCataplexy  doesn't have enough genes with high genetic scores.
# Narcolepsy
# Narcolepsy  doesn't have enough genes with high genetic scores.
# NeuroticDisorder
# NeuroticDisorder  doesn't have enough genes with high genetic scores.
# NMO
# NMO  doesn't have enough genes with high genetic scores.
# OCD
# OCD  doesn't have enough genes with high genetic scores.
# PartialEpilepsy
# PartialEpilepsy  doesn't have enough genes with high genetic scores.
# PD
# PD  doesn't have enough genes with high genetic scores.
# PrD
# PrD  doesn't have enough genes with high genetic scores.
# ProgressiveSupranuclearPalsy
# ProgressiveSupranuclearPalsy  doesn't have enough genes with high genetic scores.
# RestlessLeg
# RestlessLeg  doesn't have enough genes with high genetic scores.
# Schizophrenia
# Schizophrenia  doesn't have enough genes with high genetic scores.
# TouretteSyndrome
# TouretteSyndrome  doesn't have enough genes with high genetic scores.
# UnipolarDepression
# UnipolarDepression  doesn't have enough genes with high genetic scores.
# AD
# AD  doesn't have enough genes with high genetic scores.
# ALS
# ALS  doesn't have enough genes with high genetic scores.
# AnorexiaNervosa
# AnorexiaNervosa  doesn't have enough genes with high genetic scores.
# BipolarDisorder
# BipolarDisorder  doesn't have enough genes with high genetic scores.
# BrainAneurysm
# BrainAneurysm  doesn't have enough genes with high genetic scores.
# CerebelarAmyloidAngiopathy
# CerebelarAmyloidAngiopathy  doesn't have enough genes with high genetic scores.
# EssentialTremor
# EssentialTremor  doesn't have enough genes with high genetic scores.
# FrontotemporalDementia
# FrontotemporalDementia  doesn't have enough genes with high genetic scores.
# IntracranialHemorrhage
# IntracranialHemorrhage  doesn't have enough genes with high genetic scores.
# LBD
# LBD  doesn't have enough genes with high genetic scores.
# MajorDepressiveDisorder
# MajorDepressiveDisorder  doesn't have enough genes with high genetic scores.
# MigraineDisorder
# MigraineDisorder  doesn't have enough genes with high genetic scores.
# MigraineWithAura
# MigraineWithAura  doesn't have enough genes with high genetic scores.
# MS
# MS  doesn't have enough genes with high genetic scores.
# NarcolepsyCataplexy
# NarcolepsyCataplexy  doesn't have enough genes with high genetic scores.
# Narcolepsy
# Narcolepsy  doesn't have enough genes with high genetic scores.
# NeuroticDisorder
# NeuroticDisorder  doesn't have enough genes with high genetic scores.
# NMO
# NMO  doesn't have enough genes with high genetic scores.
# OCD
# OCD  doesn't have enough genes with high genetic scores.
# PartialEpilepsy
# PartialEpilepsy  doesn't have enough genes with high genetic scores.
# PD
# PD  doesn't have enough genes with high genetic scores.
# PrD
# PrD  doesn't have enough genes with high genetic scores.
# ProgressiveSupranuclearPalsy
# ProgressiveSupranuclearPalsy  doesn't have enough genes with high genetic scores.
# RestlessLeg
# RestlessLeg  doesn't have enough genes with high genetic scores.
# Schizophrenia
# Schizophrenia  doesn't have enough genes with high genetic scores.
# TouretteSyndrome
# TouretteSyndrome  doesn't have enough genes with high genetic scores.
# UnipolarDepression
# UnipolarDepression  doesn't have enough genes with high genetic scores.
# AD
# AD  doesn't have enough genes with high genetic scores.
# ALS
# ALS  doesn't have enough genes with high genetic scores.
# AnorexiaNervosa
# AnorexiaNervosa  doesn't have enough genes with high genetic scores.
# BipolarDisorder
# BipolarDisorder  doesn't have enough genes with high genetic scores.
# BrainAneurysm
# BrainAneurysm  doesn't have enough genes with high genetic scores.
# CerebelarAmyloidAngiopathy
# CerebelarAmyloidAngiopathy  doesn't have enough genes with high genetic scores.
# EssentialTremor
# EssentialTremor  doesn't have enough genes with high genetic scores.
# FrontotemporalDementia
# FrontotemporalDementia  doesn't have enough genes with high genetic scores.
# IntracranialHemorrhage
# IntracranialHemorrhage  doesn't have enough genes with high genetic scores.
# LBD
# LBD  doesn't have enough genes with high genetic scores.
# MajorDepressiveDisorder
# MajorDepressiveDisorder  doesn't have enough genes with high genetic scores.
# MigraineDisorder
# MigraineDisorder  doesn't have enough genes with high genetic scores.
# MigraineWithAura
# MigraineWithAura  doesn't have enough genes with high genetic scores.
# MS
# MS  doesn't have enough genes with high genetic scores.
# NarcolepsyCataplexy
# NarcolepsyCataplexy  doesn't have enough genes with high genetic scores.
# Narcolepsy
# Narcolepsy  doesn't have enough genes with high genetic scores.
# NeuroticDisorder
# NeuroticDisorder  doesn't have enough genes with high genetic scores.
# NMO
# NMO  doesn't have enough genes with high genetic scores.
# OCD
# OCD  doesn't have enough genes with high genetic scores.
# PartialEpilepsy
# PartialEpilepsy  doesn't have enough genes with high genetic scores.
# PD
# PD  doesn't have enough genes with high genetic scores.
# PrD
# PrD  doesn't have enough genes with high genetic scores.
# ProgressiveSupranuclearPalsy
# ProgressiveSupranuclearPalsy  doesn't have enough genes with high genetic scores.
# RestlessLeg
# RestlessLeg  doesn't have enough genes with high genetic scores.
# Schizophrenia
# Schizophrenia  doesn't have enough genes with high genetic scores.
# TouretteSyndrome
# TouretteSyndrome  doesn't have enough genes with high genetic scores.
# UnipolarDepression
# UnipolarDepression  doesn't have enough genes with high genetic scores.

# %%
path[n]
# Out:
# 'raw_data\\UnipolarDepression_EFO_0003761-associated-diseases.tsv'
