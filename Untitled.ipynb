# %%
###--------------------------------------------LOAD LIBRARIES
import scanpy as sc
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import copy

# %%
LR = pd.read_csv("processed_data/03-LR_network_visualisation/03h_spatial_colocalisation/LR_0.7_c2l_3cells_adjacencymatrix.csv", index_col = 0)
CT = pd.read_csv("processed_data/03-LR_network_visualisation/03h_spatial_colocalisation/Ctrl_0.7_c2l_3cells_adjacencymatrix.csv", index_col = 0)

# %%
sns.heatmap(pd.DataFrame(np.tril(LR/CT.replace(0, 1/10000000000000000)), index = LR.index, columns = LR.columns), cmap = 'inferno_r')
# Out:
# <AxesSubplot:>
